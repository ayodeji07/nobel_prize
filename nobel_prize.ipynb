# %%
# Loading in required libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
# Reading in the Nobel Prize data
nobel = pd.read_csv('Nobel_prize.csv')

# %%
# Taking a look at the first several winners
nobel.head()

#nobel['Birth Date'] = pd.to_datetime(nobel['Birth Date'])
# Out:
#    Year    Category                                           Prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           Motivation Prize Share  Laureate ID  \
# 0  "in recognition of the extraordinary services ...       1-Jan          160
# 1  "in special recognition of his poetic composit...       1-Jan          569
# 2  "for his work on serum therapy, especially its...       1-Jan          293
# 3                                                NaN       2-Jan          462
# 4                                                NaN       2-Jan          463
#
#   Laureate Type                     Full Name Birth Date         Birth City  \
# 0    Individual  Jacobus Henricus van 't Hoff 1852-08-30          Rotterdam
# 1    Individual               Sully Prudhomme 1839-03-16              Paris
# 2    Individual        Emil Adolf von Behring 1854-03-15  Hansdorf (Lawice)
# 3    Individual             Jean Henry Dunant 1828-05-08             Geneva
# 4    Individual                Frédéric Passy 1822-05-20              Paris
#
#       Birth Country   Sex   Organization Name Organization City  \
# 0       Netherlands  Male   Berlin University            Berlin
# 1            France  Male                 NaN               NaN
# 2  Prussia (Poland)  Male  Marburg University           Marburg
# 3       Switzerland  Male                 NaN               NaN
# 4            France  Male                 NaN               NaN
#
#   Organization Country  Death Date Death City Death Country
# 0              Germany    3/1/1911     Berlin       Germany
# 1                  NaN    9/7/1907   Châtenay        France
# 2              Germany   3/31/1917    Marburg       Germany
# 3                  NaN  10/30/1910     Heiden   Switzerland
# 4                  NaN   6/12/1912      Paris        France

# %%
# Display the number of Nobel Prizes handed out between 1901 and 2016

print(len(nobel))
# Out:
# 969

# %%
# Display the number of prizes won by male and female recipients.
print(nobel['Sex'].value_counts())
# Out:
# Male      893
# Female     50
# Name: Sex, dtype: int64

# %%
# Display the number of prizes won by the top 10 nationalities.
nobel['Birth Country'].value_counts().head(10)
# Out:
# United States of America    276
# United Kingdom               88
# Germany                      70
# France                       53
# Sweden                       30
# Japan                        29
# Russia                       20
# Netherlands                  19
# Italy                        18
# Canada                       18
# Name: Birth Country, dtype: int64

# %%
# Calculating the proportion of USA born winners per decade
nobel['Usa Born Winners'] = nobel['Birth Country'] == 'United States of America'
nobel['Decade'] = (np.floor(nobel['Year'] / 10) * 10).astype(int)
prop_usa_winners = nobel.groupby('Decade', as_index=False)['Usa Born Winners'].mean()

# Display the proportions of USA born winners per decade
prop_usa_winners
# Out:
#     Decade  Usa Born Winners
# 0     1900          0.017241
# 1     1910          0.075000
# 2     1920          0.074074
# 3     1930          0.241935
# 4     1940          0.288889
# 5     1950          0.278481
# 6     1960          0.262500
# 7     1970          0.308411
# 8     1980          0.313131
# 9     1990          0.392523
# 10    2000          0.414286
# 11    2010          0.336735

# %%
# Setting the plotting theme
sns.set()

# setting the size of all plots.
plt.rcParams['figure.figsize'] = [11, 7]

# Plotting USA born winners 
ax = sns.lineplot(x='Decade', y='Usa Born Winners', data=prop_usa_winners)

# Adding %-formatting to the y-axis
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter(1,0))

# %%
# Calculating the proportion of female laureates per decade
nobel['Female Winner'] = nobel['Sex'] == 'Female'
prop_female_winners = nobel.groupby(['Decade', 'Category'], as_index=False)['Female Winner'].mean()

# Plotting USA born winners with % winners on the y-axis
plt.rcParams['figure.figsize'] = [11, 7]
ax = sns.lineplot(x = 'Decade', y = 'Female Winner', data = prop_female_winners, hue = 'Category')

ax.yaxis.set_major_formatter(PercentFormatter(1,0))

# %%
# Picking out the first woman to win a Nobel Prize
nobel[nobel.Sex == 'Female'].nsmallest(1, 'Year')
# Out:
#     Year Category                            Prize  \
# 19  1903  Physics  The Nobel Prize in Physics 1903
#
#                                            Motivation Prize Share  \
# 19  "in recognition of the extraordinary services ...       4-Jan
#
#     Laureate ID Laureate Type                    Full Name Birth Date  \
# 19            6    Individual  Marie Curie, née Sklodowska 1867-11-07
#
#    Birth City  ...     Sex Organization Name Organization City  \
# 19     Warsaw  ...  Female               NaN               NaN
#
#    Organization Country Death Date  Death City Death Country Usa Born Winners  \
# 19                  NaN   7/4/1934  Sallanches        France            False
#
#     Decade  Female Winner
# 19    1900           True
#
# [1 rows x 21 columns]

# %%
# Selecting the laureates that have received 2 or more prizes.
nobel.groupby('Full Name').filter(lambda group : len(group) >= 2 )
# Out:
#      Year   Category                                           Prize  \
# 19   1903    Physics                 The Nobel Prize in Physics 1903
# 46   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 47   1908   Medicine  The Nobel Prize in Physiology or Medicine 1908
# 63   1911  Chemistry               The Nobel Prize in Chemistry 1911
# 90   1917      Peace                      The Nobel Peace Prize 1917
# ..    ...        ...                                             ...
# 942  2014    Physics                 The Nobel Prize in Physics 2014
# 945  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 946  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 947  2015  Chemistry               The Nobel Prize in Chemistry 2015
# 948  2015  Chemistry               The Nobel Prize in Chemistry 2015
#
#                                             Motivation Prize Share  \
# 19   "in recognition of the extraordinary services ...       4-Jan
# 46          "in recognition of their work on immunity"       2-Jan
# 47          "in recognition of their work on immunity"       2-Jan
# 63   "in recognition of her services to the advance...       1-Jan
# 90                                                 NaN       1-Jan
# ..                                                 ...         ...
# 942  "for the invention of efficient blue light-emi...       3-Jan
# 945            "for mechanistic studies of DNA repair"       3-Jan
# 946            "for mechanistic studies of DNA repair"       3-Jan
# 947            "for mechanistic studies of DNA repair"       3-Jan
# 948            "for mechanistic studies of DNA repair"       3-Jan
#
#      Laureate ID Laureate Type  \
# 19             6    Individual
# 46           302    Individual
# 47           302    Individual
# 63             6    Individual
# 90           482  Organization
# ..           ...           ...
# 942          906    Individual
# 945          921    Individual
# 946          921    Individual
# 947          922    Individual
# 948          922    Individual
#
#                                              Full Name Birth Date  \
# 19                         Marie Curie, née Sklodowska 1867-11-07
# 46                                        Paul Ehrlich 1854-03-14
# 47                                        Paul Ehrlich 1854-03-14
# 63                         Marie Curie, née Sklodowska 1867-11-07
# 90   Comité international de la Croix Rouge (Intern...        NaT
# ..                                                 ...        ...
# 942                                      Isamu Akasaki 1929-01-30
# 945                                      Tomas Lindahl 1938-01-28
# 946                                      Tomas Lindahl 1938-01-28
# 947                                       Paul Modrich 1946-06-13
# 948                                       Paul Modrich 1946-06-13
#
#               Birth City  ...     Sex  \
# 19                Warsaw  ...  Female
# 46   Strehlen (Strzelin)  ...    Male
# 47   Strehlen (Strzelin)  ...    Male
# 63                Warsaw  ...  Female
# 90                   NaN  ...     NaN
# ..                   ...  ...     ...
# 942               Chiran  ...    Male
# 945            Stockholm  ...    Male
# 946            Stockholm  ...    Male
# 947            Raton, NM  ...    Male
# 948            Raton, NM  ...    Male
#
#                                      Organization Name      Organization City  \
# 19                                                 NaN                    NaN
# 46                               Goettingen University              Göttingen
# 47   Königliches Institut für experimentelle Therap...  Frankfurt-on-the-Main
# 63                                 Sorbonne University                  Paris
# 90                                                 NaN                    NaN
# ..                                                 ...                    ...
# 942                                  Nagoya University                 Nagoya
# 945                            Francis Crick Institute          Hertfordshire
# 946                              Clare Hall Laboratory          Hertfordshire
# 947                    Howard Hughes Medical Institute             Durham, NC
# 948                 Duke University School of Medicine             Durham, NC
#
#          Organization Country Death Date                Death City  \
# 19                        NaN   7/4/1934                Sallanches
# 46                    Germany  8/20/1915  Bad Homburg vor der Höhe
# 47                    Germany  8/20/1915  Bad Homburg vor der Höhe
# 63                     France   7/4/1934                Sallanches
# 90                        NaN        NaN                       NaN
# ..                        ...        ...                       ...
# 942                     Japan        NaN                       NaN
# 945            United Kingdom        NaN                       NaN
# 946            United Kingdom        NaN                       NaN
# 947  United States of America        NaN                       NaN
# 948  United States of America        NaN                       NaN
#
#     Death Country Usa Born Winners  Decade  Female Winner
# 19         France            False    1900           True
# 46        Germany            False    1900          False
# 47        Germany            False    1900          False
# 63         France            False    1910           True
# 90            NaN            False    1910          False
# ..            ...              ...     ...            ...
# 942           NaN            False    2010          False
# 945           NaN            False    2010          False
# 946           NaN            False    2010          False
# 947           NaN             True    2010          False
# 948           NaN             True    2010          False
#
# [128 rows x 21 columns]

# %%
# Converting birth_date from String to datetime
nobel['Birth Date'] = pd.to_datetime(nobel['Birth Date'])

# Calculating the age of Nobel Prize winners
nobel['Age'] = nobel['Year'] - nobel['Birth Date'].dt.year

#Plotting the age of Nobel Prize winners
sns.lmplot(x = 'Year', y = 'Age', data = nobel, lowess = True, aspect = 2, line_kws={'color' : 'black'})

# %%
# Same plot as above, but separate plots for each type of Nobel Prize
sns.lmplot(x = 'Year', y = 'Age', data = nobel, row = 'Category', lowess = True, aspect = 2, line_kws={'color' : 'black'})

# %%
# The oldest winner of a Nobel Prize as of 2016
oldest_winner = nobel.nlargest(1, 'Age')
display(oldest_winner)

# The youngest winner of a Nobel Prize as of 2016
youngest_winner = nobel.nsmallest(1, 'Age')
display(youngest_winner)
# Out:
#      Year   Category                                              Prize  \
# 825  2007  Economics  The Sveriges Riksbank Prize in Economic Scienc...
#
#                                             Motivation Prize Share  \
# 825  "for having laid the foundations of mechanism ...       3-Jan
#
#      Laureate ID Laureate Type       Full Name Birth Date Birth City  ...  \
# 825          820    Individual  Leonid Hurwicz 1917-08-21     Moscow  ...
#
#            Organization Name Organization City      Organization Country  \
# 825  University of Minnesota   Minneapolis, MN  United States of America
#
#     Death Date       Death City             Death Country Usa Born Winners  \
# 825  6/24/2008  Minneapolis, MN  United States of America            False
#
#     Decade  Female Winner   Age
# 825   2000          False  90.0
#
# [1 rows x 22 columns]
#      Year Category                       Prize  \
# 940  2014    Peace  The Nobel Peace Prize 2014
#
#                                             Motivation Prize Share  \
# 940  "for their struggle against the suppression of...       2-Jan
#
#      Laureate ID Laureate Type         Full Name Birth Date Birth City  ...  \
# 940          914    Individual  Malala Yousafzai 1997-07-12    Mingora  ...
#
#     Organization Name Organization City Organization Country Death Date  \
# 940               NaN               NaN                  NaN        NaN
#
#     Death City Death Country Usa Born Winners Decade  Female Winner   Age
# 940        NaN           NaN            False   2010           True  17.0
#
# [1 rows x 22 columns]
